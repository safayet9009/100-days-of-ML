# %%
import requests
import pandas as pd

url = 'https://www.imdb.com/title/tt0816692/'  # Replace with actual API URL

headers = {
    "X-RapidAPI-Key": "e51124b757msh36c50ee61bc19c9p107e06jsn8f4d7a294f3a",      # Replace with your key
    "X-RapidAPI-Host": "imdb236.p.rapidapi.com"
}

response = requests.get(url, headers=headers)
data = response.json()

# ধরে নিচ্ছি data একটা list of dicts
df = pd.DataFrame(data)

# CSV ফাইলে save করা
df.to_csv("api_data.csv", index=False)
print("CSV file saved!")
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\requests\models.py:974, in Response.json(self, **kwargs)
#     973 try:
# --> 974     return complexjson.loads(self.text, **kwargs)
#     975 except JSONDecodeError as e:
#     976     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     977     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~\anaconda3\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# ...

# %%
import requests
import pandas as pd

url = "https://imdb236.p.rapidapi.com/api/imdb/tt0816692/tmdb"

headers = {
    "X-RapidAPI-Key": "e51124b757msh36c50ee61bc19c9p107e06jsn8f4d7a294f3a",
    "X-RapidAPI-Host": "imdb236.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

# Debugging outputs
print("Status Code:", response.status_code)
print("Response Text:", response.text)  # See what's returned

# Only parse JSON if it's successful
if response.status_code == 200:
    data = response.json()
    df = pd.json_normalize(data)
    df.to_csv("imdb_movie_data.csv", index=False)
    print("✅ CSV saved!")
else:
    print("❌ API call failed. Check your URL, headers or subscription.")
# Out:
# Status Code: 404
# Response Text: {"message":"Endpoint '\/api\/imdb\/tt0816692\/tmdb' does not exist"}
# ❌ API call failed. Check your URL, headers or subscription.

# %%
import requests
import pandas as pd

# ✅ সঠিক API endpoint
url = "https://imdb236.p.rapidapi.com/movie_imdb_id?movieid=tt0816692"

headers = {
    "X-RapidAPI-Key": "e51124b757msh36c50ee61bc19c9p107e06jsn8f4d7a294f3a",
    "X-RapidAPI-Host": "imdb236.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print("Status Code:", response.status_code)
print("Response Text (partial):", response.text[:300])  # Just to see sample

if response.status_code == 200:
    data = response.json()
    
    # JSON to flat DataFrame
    df = pd.json_normalize(data)
    df.to_csv("interstellar_movie.csv", index=False)
    print("✅ CSV file saved as 'interstellar_movie.csv'")
else:
    print("❌ API call failed. Check key or endpoint.")
# Out:
# Status Code: 404
# Response Text (partial): {"message":"Endpoint '\/movie_imdb_id' does not exist"}
# ❌ API call failed. Check key or endpoint.

# %%
import requests
import pandas as pd

# ✅ IMDb Top 100 Movies API endpoint
url = "https://imdb-top-100-movies.p.rapidapi.com/top"

headers = {
    "X-RapidAPI-Key": "e51124b757msh36c50ee61bc19c9p107e06jsn8f4d7a294f3a",
    "X-RapidAPI-Host": "imdb-top-100-movies.p.rapidapi.com"  # আগের লাইনে কমা থাকতে হবে
}

response = requests.get(url, headers=headers)

# ✅ Check status and save CSV
if response.status_code == 200:
    data = response.json()
    df = pd.DataFrame(data)
    df.to_csv("imdb_top_100_movies.csv", index=False)
    print("✅ CSV file saved as 'imdb_top_100_movies.csv'")
else:
    print("❌ Error:", response.status_code)
    print("Response text:", response.text)
# Out:
# ❌ Error: 400
# Response text: "Bad Request : Invalid movie id"

# %%
import requests
import pandas as pd

url = "https://imdb-top-100-movies.p.rapidapi.com/top"

headers = {
    "X-RapidAPI-Key": "e51124b757msh36c50ee61bc19c9p107e06jsn8f4d7a294f3a",
    "X-RapidAPI-Host": "imdb-top-100-movies.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print("Status Code:", response.status_code)

if response.status_code == 200:
    data = response.json()
    df = pd.DataFrame(data)
    df.to_csv("imdb_top_100_movies.csv", index=False)
    print("✅ CSV saved as 'imdb_top_100_movies.csv'")
else:
    print("❌ Error:", response.status_code)
    print("Response Text:", response.text)
# Out:
# Status Code: 400
# ❌ Error: 400
# Response Text: "Bad Request : Invalid movie id"

# %%
import requests
import pandas as pd

# ✅ সঠিক endpoint (NO movie id!)
url = "https://imdb-top-100-movies.p.rapidapi.com/top"

headers = {
    "X-RapidAPI-Key": "e51124b757msh36c50ee61bc19c9p107e06jsn8f4d7a294f3a",
    "X-RapidAPI-Host": "imdb-top-100-movies.p.rapidapi.com"
}

# API Request
response = requests.get(url, headers=headers)

# Debugging
print("Status Code:", response.status_code)

if response.status_code == 200:
    data = response.json()  # List of movie dicts
    df = pd.DataFrame(data)
    df.to_csv("imdb_top_100_movies.csv", index=False)
    print("✅ CSV file saved as 'imdb_top_100_movies.csv'")
else:
    print("❌ Error:", response.status_code)
    print("Response Text:", response.text)
# Out:
# Status Code: 400
# ❌ Error: 400
# Response Text: "Bad Request : Invalid movie id"

# %%
import requests
import pandas as pd

# ✅ Correct URL – Do not change this
url = "https://imdb-top-100-movies.p.rapidapi.com/top"

# ✅ Use your working API key
headers = {
    "X-RapidAPI-Key": "e51124b757msh36c50ee61bc19c9p107e06jsn8f4d7a294f3a",
    "X-RapidAPI-Host": "imdb-top-100-movies.p.rapidapi.com"
}

# ✅ Make the GET request
response = requests.get(url, headers=headers)

# ✅ Check if successful
print("Status Code:", response.status_code)

if response.status_code == 200:
    # Parse JSON and convert to DataFrame
    data = response.json()
    df = pd.DataFrame(data)

    # Save to CSV
    df.to_csv("imdb_top_100_movies.csv", index=False)
    print("✅ IMDb Top 100 CSV saved successfully as 'imdb_top_100_movies.csv'")
else:
    print("❌ Error:", response.status_code)
    print("Response Text:", response.text)
# Out:
# Status Code: 400
# ❌ Error: 400
# Response Text: "Bad Request : Invalid movie id"

# %%
import requests
import pandas as pd

# 📌 সঠিক API endpoint
url = "https://imdb-top-100-movies.p.rapidapi.com/top"

headers = {
    "X-RapidAPI-Key": "e51124b757msh36c50ee61bc19c9p107e06jsn8f4d7a294f3a",
    "X-RapidAPI-Host": "imdb-top-100-movies.p.rapidapi.com"
}

# GET request
response = requests.get(url, headers=headers)

print("Status Code:", response.status_code)

if response.status_code == 200:
    data = response.json()
    df = pd.DataFrame(data)
    df.to_csv("imdb_top_100_movies.csv", index=False)
    print("✅ CSV saved as 'imdb_top_100_movies.csv'")
else:
    print("❌ Error occurred!")
    print("Response Text:", response.text)
# Out:
# Status Code: 400
# ❌ Error occurred!
# Response Text: "Bad Request : Invalid movie id"

# %%
import requests
import pandas as pd

url = 'https://www.imdb.com/title/tt0816692/'  # Replace with actual API URL

headers = {
    "X-RapidAPI-Key": "e51124b757msh36c50ee61bc19c9p107e06jsn8f4d7a294f3a",      # Replace with your key
    "X-RapidAPI-Host": "imdb236.p.rapidapi.com"
}

response = requests.get(url, headers=headers)
data = response.json()

# ধরে নিচ্ছি data একটা list of dicts
df = pd.DataFrame(data)

# CSV ফাইলে save করা
df.to_csv("api_data.csv", index=False)
print("CSV file saved!")

# %%
import requests
import pandas as pd

# ✅ API endpoint (DO NOT change)
url = "https://imdb-top-100-movies.p.rapidapi.com/"

# ✅ Headers with your API key and host
headers = {
    "X-RapidAPI-Key": "e51124b757msh36c50ee61bc19c9p107e06jsn8f4d7a294f3a",
    "X-RapidAPI-Host": "imdb-top-100-movies.p.rapidapi.com"
}

# ✅ GET request
response = requests.get(url, headers=headers)

print("Status Code:", response.status_code)

# ✅ Success block
if response.status_code == 200:
    data = response.json()
    
    # View structure if needed
    print("First item example:", data[0])
    
    # Convert list of dicts to DataFrame
    df = pd.DataFrame(data)
    
    # Save to CSV
    df.to_csv("imdb_top_100_movies.csv", index=False)
    print("✅ CSV file 'imdb_top_100_movies.csv' saved successfully!")
else:
    print("❌ Request Failed!")
    print("Response Text:", response.text)
# Out:
# Status Code: 200
# First item example: {'rank': 1, 'title': 'The Shawshank Redemption', 'description': 'Two imprisoned men bond over a number of years, finding solace and eventual redemption through acts of common decency.', 'image': 'https://m.media-amazon.com/images/M/MV5BMDFkYTc0MGEtZmNhMC00ZDIzLWFmNTEtODM1ZmRlYWMwMWFmXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_QL75_UX380_CR0,1,380,562_.jpg', 'big_image': 'https://m.media-amazon.com/images/M/MV5BMDFkYTc0MGEtZmNhMC00ZDIzLWFmNTEtODM1ZmRlYWMwMWFmXkEyXkFqcGdeQXVyMTMxODk2OTU@', 'genre': ['Drama'], 'thumbnail': 'https://m.media-amazon.com/images/M/MV5BMDFkYTc0MGEtZmNhMC00ZDIzLWFmNTEtODM1ZmRlYWMwMWFmXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_UY67_CR0,0,45,67_AL_.jpg', 'rating': '9.3', 'id': 'top1', 'year': 1994, 'imdbid': 'tt0111161', 'imdb_link': 'https://www.imdb.com/title/tt0111161'}
# ✅ CSV file 'imdb_top_100_movies.csv' saved successfully!
